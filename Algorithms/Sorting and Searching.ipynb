# %%
# Searching Techniques

def search(arr, data):
    """
    Search an item in a list linearly.
    
    Time complexity - O(n)
    Space complexity - O(1)
    """
    if arr is None or data is None:
        return False
    else:
        for x in arr:
            if data == arr:
                return True
        return False
    
    
def iterative_binary_search(arr, data):
    """
    Perform binary search on a list iteratively.
    
    Time complexity - O(log n)
    Space complexity - O(1)
    """
    if arr is None or len(arr) == 0:
        return False
    else:
        low = 0
        high = len(arr)-1
        while low < high:
            mid = low + (high-low)/2
            if data < arr[mid]:
                high = mid
            elif data > arr[mid]:
                low = mid+1
            else:
                return True
        return False

                
def recursive_binary_search(arr, data, low, high):
    """
    Perform binary search on a list recursively.
    
    Time complexity - O(log n)
    Space complexity - O(1)
    """
    if low > high:
        return False
    else:
        mid = low + (high-low)/2
        if data == arr[mid]:
            return True
        elif data > arr[mid]:
            recursive_binary_search(arr, data, mid+1, high)
        else:
            recursive_binary_search(arr, data, low, mid-1)

# %%
# Sorting Techniques

def bubble_sort(arr):
    """
    Sort a list using bubble sort technique.
    
    Time complexity - O(n^2)
    Space complexity - O(1)
    """
    arr_size = len(arr)
    for i in xrange(arr_size):
        for j in xrange(i, arr_size):
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]
                
    return arr


def insertion_sort(arr):
    """
    Insertion sort.
    
    Time complexity - O(n^2)
    Space complexity - O(1)
    """
    arr_size = len(arr)
    for i in xrange(1, arr_size):
        key = arr[i]
        j = i-1
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key    
        
    return arr


def selection_sort(arr):
    """
    Selection sort.
    
    Time complexity - O(n^2)
    Space complexity - O(1)
    """
    arr_size = len(arr)
    for i in xrange(arr_size):
        min_index = i
        for j in xrange(i, arr_size):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    
    return arr

# %%
def quicksort(arr):
    """
    Interesting way of quicksort.
    
    Time complexity - O(nlogn)
    Space complexity - O(n)
    """
    if len(arr) > 1:
        less = []
        equal = []
        greater = []
        pivot = arr[0]
        
        for i in xrange(len(arr)):
            if arr[i] < pivot:
                less.append(arr[i])
            elif arr[i] > pivot:
                greater.append(arr[i])
            else:
                equal.append(arr[i])
        
        return quicksort(less) + equal + quicksort(greater)
    else:
        return arr
    
    
def partition(arr, low, high):
    
    
def quick_sort(arr):
    """
    Traditional way of quick sort.
    
    Time complexity - O(nlogn)
    Space complexity - O(n)
    """
    pass
