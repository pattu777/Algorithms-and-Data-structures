# %%
# Permutations of a string

def permutations(data, start, end):
    if start == end:
        print data
    else:
        for x in xrange(start, end+1):
            data[start], data[x] = data[x], data[start]
            permutations(data, start+x, end)
            data[start], data[x] = data[x], data[start]
            
data = "ABC"
permutations(data, 0, len(data)-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-fc90bed1e7dd> in <module>()
#      11
#      12 data = "ABC"
# ---> 13 permutations(data, 0, len(data)-1)
#
# <ipython-input-1-fc90bed1e7dd> in permutations(data, start, end)
#       6     else:
#       7         for x in xrange(start, end+1):
# ----> 8             data[start], data[x] = data[x], data[start]
#       9             permutations(data, start+x, end)
#      10             data[start], data[x] = data[x], data[start]
#
# TypeError: 'str' object does not support item assignment

# %%
# Calculate power(x, n)

from nose.tools import assert_equal

def power(x, n):
    """Calcuate pow(x,n)"""
    if n < 2:
        return x
    
    val = power(x, n/2)
    if n%2 == 0:
        return val * val
    else:
        return x * val * val
    
    
class TestProblems(object):
    def test_power(self, solution):
        assert_equal(solution(0, 2), 0)
        assert_equal(solution(1, 12312), 1)
        assert_equal(solution(2, 10), 1024)
        assert_equal(solution(10, 4), 10000)
        print 'Success: test_power'


def main():
    test = TestProblems()
    test.test_power(power)
    

if __name__ == '__main__':
    main()
# Out:
# Success: test_power

# %%
(2**32)-1
# Out:
# 4294967296
